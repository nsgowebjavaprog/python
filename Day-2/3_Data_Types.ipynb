# %%
# Data Types

# 1.Integers

age = 20
type(age)

height = 5.10
type(height)

name = "NS LONI"
type(name)

is_student = True
type(is_student)
# Out:
# bool

# %%
result = "HELLO" + 5
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = "HELLO" + 5
#       2 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
result = "HELLO" + str(5)
print(result)
# Out:
# HELLO5
